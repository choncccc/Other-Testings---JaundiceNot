# %% [markdown]
# ## MODEL USING HISTOGRAM

# %%
import os
import time
import numpy as np
import io
import cv2
import pandas as pd
from sklearn.utils import shuffle
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.utils import load_img, img_to_array

# %%
def extract_yellow_histogram_features(image, bins=10):
    lab_image = cv2.cvtColor(image.astype(np.uint8), cv2.COLOR_RGB2LAB)
    L, A, B = lab_image[:, :, 0], lab_image[:, :, 1], lab_image[:, :, 2]

    iris_mask = L < 70
    skin_mask = (A > 130) & (B > 130)
    valid_mask = ~(iris_mask | skin_mask)

    L_valid, A_valid, B_valid = L[valid_mask], A[valid_mask], B[valid_mask]

    if L_valid.size == 0:
        return np.zeros(bins * 3)

    L_hist = np.histogram(L_valid / 255.0, bins=bins, range=(0, 1), density=True)[0]
    A_hist = np.histogram((A_valid + 128) / 255.0, bins=bins, range=(0, 1), density=True)[0]
    B_hist = np.histogram((B_valid + 128) / 255.0, bins=bins, range=(0, 1), density=True)[0]

    feature_vector = np.concatenate([L_hist, A_hist, B_hist])

    return feature_vector


def load_images_and_labels(folder, label, bins=10):
    images = []
    for file in os.listdir(folder):
        image_path = os.path.join(folder, file)
        image = tf.keras.utils.img_to_array(tf.keras.utils.load_img(image_path))
        color_features = extract_yellow_histogram_features(image, bins)
        images.append(color_features.reshape(1, -1))
    labels = [label] * len(images)
    return np.vstack(images), np.array(labels)

train_jaundiced_images, train_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/train", 1
    )
train_healthy_images, train_healthy_labels = load_images_and_labels(
    "./new/Normal Class/train", 0
    )

X_train = np.vstack((train_jaundiced_images, train_healthy_images))
y_train = np.hstack((train_jaundiced_labels, train_healthy_labels))

X_train, y_train = shuffle(X_train, y_train, random_state=1)

test_jaundiced_images, test_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/test", 1
    )
test_healthy_images, test_healthy_labels = load_images_and_labels(
    "./new/Normal Class/test", 0
    )

X_test = np.vstack((test_jaundiced_images, test_healthy_images))
y_test = np.hstack((test_jaundiced_labels, test_healthy_labels))

val_jaundiced_images, val_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/validate", 1
    )
val_healthy_images, val_healthy_labels = load_images_and_labels(
    "./new/Normal Class/validate", 0
    )

X_val = np.vstack((val_jaundiced_images, val_healthy_images))
y_val = np.hstack((val_jaundiced_labels, val_healthy_labels))

print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Jaundiced images shape:", train_jaundiced_images.shape)
print("Healthy images shape:", train_healthy_images.shape)
print("X_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
print("First 5 rows of X_train:", X_train[:5])
# Out:
# Test data shape: (241, 30)
# Validation data shape: (245, 30)
# Jaundiced images shape: (334, 30)
# Healthy images shape: (392, 30)
# X_train shape: (726, 30)
# X_train dtype: float64
# First 5 rows of X_train: [[0.         0.         0.11846002 0.33563672 0.31589339 0.38499506
#   1.56959526 2.11253702 4.75814413 0.4047384  6.6041461  0.
#   0.         0.         0.         0.         0.         0.
#   0.         3.3958539  6.93978282 2.36920039 0.         0.
#   0.         0.         0.         0.         0.         0.69101678]
#  [0.         0.         0.78307831 2.38073807 1.80468047 1.18811881
#   0.69306931 0.56255626 0.50405041 2.08370837 7.51575158 0.
#   0.         0.         0.         0.         0.         0.
#   0.         2.48424842 4.13591359 0.         0.         0.
#   0.         0.         0.         0.         0.         5.86408641]
#  [0.         0.         0.10282776 0.61696658 1.20822622 1.67095116
#   2.00514139 2.75064267 1.64524422 0.         6.94087404 0.
#   0.         0.         0.         0.         0.         0.
#   0.         3.05912596 4.91002571 2.13367609 0.         0.
#   0.         0.         0.         0.         0.         2.9562982 ]
#  [0.         0.         0.32786885 1.8852459  1.80327869 1.06557377
#   1.77595628 1.8579235  1.2295082  0.05464481 5.79234973 0.
#   0.         0.         0.         0.         0.         0.
#   0.         4.20765027 3.79781421 0.         0.         0.
#   0.         0.         0.         0.         0.         6.20218579]
#  [0.         0.         0.05586592 1.06145251 1.00558659 0.94972067
#   1.67597765 1.17318436 0.16759777 3.91061453 8.2122905  0.
#   0.         0.         0.         0.         0.         0.
#   0.         1.7877095  9.94413408 0.         0.         0.
#   0.         0.         0.         0.         0.         0.05586592]]

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (726, 30)
# X_test shape: (241, 30)
# X_val shape: (245, 30)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Fit 
X_test = scaler.transform(X_test)       # Transform test data (images only with no annotations but with features)
X_val = scaler.transform(X_val)

# %%
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.01), input_dim=X_train.shape[1]),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, kernel_regularizer=l2(0.01)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

# Callbacks Early Stopping and Reduce LR on Plateau
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=7, restore_best_weights=True)  
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

#Training
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_scheduler]
)

elapsed_time = time.time() - start_time

# Evaluate Model
loss, accuracy, precision, recall = model.evaluate(X_test, y_test)
stopped_epoch = early_stopping.stopped_epoch

print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}, Test Precision: {precision:.4f}, Test Recall: {recall:.4f}")
print(f"Training stopped at Epoch: {stopped_epoch}, Time Taken: {elapsed_time:.2f} sec")
# Out:
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7177 - loss: 5.7207 - precision_4: 0.7174 - recall_4: 0.6753 - val_accuracy: 0.8286 - val_loss: 5.3725 - val_precision_4: 0.8034 - val_recall_4: 0.8319 - learning_rate: 5.0000e-04
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8021 - loss: 5.1828 - precision_4: 0.7679 - recall_4: 0.7529 - val_accuracy: 0.8531 - val_loss: 4.9173 - val_precision_4: 0.8031 - val_recall_4: 0.9027 - learning_rate: 5.0000e-04
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8263 - loss: 4.7880 - precision_4: 0.8230 - recall_4: 0.7826 - val_accuracy: 0.8531 - val_loss: 4.5144 - val_precision_4: 0.8598 - val_recall_4: 0.8142 - learning_rate: 5.0000e-04
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8490 - loss: 4.3958 - precision_4: 0.8664 - recall_4: 0.8049 - val_accuracy: 0.8612 - val_loss: 4.1419 - val_precision_4: 0.8624 - val_recall_4: 0.8319 - learning_rate: 5.0000e-04
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8231 - loss: 4.1573 - precision_4: 0.8213 - recall_4: 0.7813 - val_accuracy: 0.8776 - val_loss: 3.8102 - val_precision_4: 0.9192 - val_recall_4: 0.8053 - learning_rate: 5.0000e-04
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8863 - loss: 3.7125 - precision_4: 0.8823 - recall_4: 0.8675 - val_accuracy: 0.8980 - val_loss: 3.5231 - val_precision_4: 0.9583 - val_recall_4: 0.8142 - learning_rate: 5.0000e-04
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8677 - loss: 3.4598 - precision_4: 0.8949 - recall_4: 0.8287 - val_accuracy: 0.8857 - val_loss: 3.2346 - val_precision_4: 0.8972 - val_recall_4: 0.8496 - learning_rate: 5.0000e-04
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8699 - loss: 3.1602 - precision_4: 0.8621 - recall_4: 0.8633 - val_accuracy: 0.8939 - val_loss: 2.9897 - val_precision_4: 0.9223 - val_recall_4: 0.8407 - learning_rate: 5.0000e-04
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9197 - loss: 2.8890 - precision_4: 0.9128 - recall_4: 0.8996 - val_accuracy: 0.8980 - val_loss: 2.7474 - val_precision_4: 0.9151 - val_recall_4: 0.8584 - learning_rate: 5.0000e-04
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8877 - loss: 2.7280 - precision_4: 0.8754 - recall_4: 0.8901 - val_accuracy: 0.8653 - val_loss: 2.6619 - val_precision_4: 0.8846 - val_recall_4: 0.8142 - learning_rate: 5.0000e-04
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 2.5489 - precision_4: 0.8679 - recall_4: 0.8521 - val_accuracy: 0.8898 - val_loss: 2.3912 - val_precision_4: 0.9388 - val_recall_4: 0.8142 - learning_rate: 5.0000e-04
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8909 - loss: 2.3193 - precision_4: 0.8807 - recall_4: 0.8736 - val_accuracy: 0.9143 - val_loss: 2.1388 - val_precision_4: 0.9340 - val_recall_4: 0.8761 - learning_rate: 5.0000e-04
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9112 - loss: 2.0737 - precision_4: 0.9101 - recall_4: 0.9016 - val_accuracy: 0.9306 - val_loss: 1.9661 - val_precision_4: 0.9800 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8878 - loss: 1.9806 - precision_4: 0.9016 - recall_4: 0.8473 - val_accuracy: 0.9020 - val_loss: 1.8470 - val_precision_4: 0.9159 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 1.7783 - precision_4: 0.8691 - recall_4: 0.9038 - val_accuracy: 0.8816 - val_loss: 1.7426 - val_precision_4: 0.8750 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8746 - loss: 1.6993 - precision_4: 0.8872 - recall_4: 0.8600 - val_accuracy: 0.9102 - val_loss: 1.5520 - val_precision_4: 0.9252 - val_recall_4: 0.8761 - learning_rate: 5.0000e-04
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9005 - loss: 1.5718 - precision_4: 0.9053 - recall_4: 0.8772 - val_accuracy: 0.9143 - val_loss: 1.5527 - val_precision_4: 0.9510 - val_recall_4: 0.8584 - learning_rate: 5.0000e-04
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8970 - loss: 1.5025 - precision_4: 0.8953 - recall_4: 0.8811 - val_accuracy: 0.9184 - val_loss: 1.3826 - val_precision_4: 0.9895 - val_recall_4: 0.8319 - learning_rate: 5.0000e-04
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9249 - loss: 1.3119 - precision_4: 0.9092 - recall_4: 0.9249 - val_accuracy: 0.9061 - val_loss: 1.3475 - val_precision_4: 0.8879 - val_recall_4: 0.9115 - learning_rate: 5.0000e-04
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8915 - loss: 1.2831 - precision_4: 0.8690 - recall_4: 0.8913 - val_accuracy: 0.8980 - val_loss: 1.2388 - val_precision_4: 0.9074 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 21/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8878 - loss: 1.2172 - precision_4: 0.8912 - recall_4: 0.8705 - val_accuracy: 0.9347 - val_loss: 1.1047 - val_precision_4: 0.9802 - val_recall_4: 0.8761 - learning_rate: 5.0000e-04
# Epoch 22/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9176 - loss: 1.0831 - precision_4: 0.9199 - recall_4: 0.9016 - val_accuracy: 0.9265 - val_loss: 1.0398 - val_precision_4: 0.9798 - val_recall_4: 0.8584 - learning_rate: 5.0000e-04
# Epoch 23/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9203 - loss: 0.9904 - precision_4: 0.9013 - recall_4: 0.9188 - val_accuracy: 0.9510 - val_loss: 0.9592 - val_precision_4: 0.9469 - val_recall_4: 0.9469 - learning_rate: 5.0000e-04
# Epoch 24/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8848 - loss: 1.0667 - precision_4: 0.8344 - recall_4: 0.9045 - val_accuracy: 0.9184 - val_loss: 0.9246 - val_precision_4: 0.9429 - val_recall_4: 0.8761 - learning_rate: 5.0000e-04
# Epoch 25/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9245 - loss: 0.9324 - precision_4: 0.9143 - recall_4: 0.9283 - val_accuracy: 0.9347 - val_loss: 0.8670 - val_precision_4: 0.9450 - val_recall_4: 0.9115 - learning_rate: 5.0000e-04
# Epoch 26/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9113 - loss: 0.9089 - precision_4: 0.9073 - recall_4: 0.9042 - val_accuracy: 0.9102 - val_loss: 0.8687 - val_precision_4: 0.9596 - val_recall_4: 0.8407 - learning_rate: 5.0000e-04
# Epoch 27/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9072 - loss: 0.8528 - precision_4: 0.9154 - recall_4: 0.8845 - val_accuracy: 0.9143 - val_loss: 0.8424 - val_precision_4: 0.9694 - val_recall_4: 0.8407 - learning_rate: 5.0000e-04
# Epoch 28/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 0.7626 - precision_4: 0.9061 - recall_4: 0.9304 - val_accuracy: 0.8857 - val_loss: 0.8553 - val_precision_4: 0.8829 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 29/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9038 - loss: 0.8177 - precision_4: 0.9213 - recall_4: 0.8631 - val_accuracy: 0.8939 - val_loss: 0.8217 - val_precision_4: 0.9888 - val_recall_4: 0.7788 - learning_rate: 5.0000e-04
# Epoch 30/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9070 - loss: 0.7777 - precision_4: 0.9027 - recall_4: 0.8863 - val_accuracy: 0.9143 - val_loss: 0.7932 - val_precision_4: 0.9423 - val_recall_4: 0.8673 - learning_rate: 5.0000e-04
# Epoch 31/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9233 - loss: 0.7679 - precision_4: 0.8875 - recall_4: 0.9401 - val_accuracy: 0.9347 - val_loss: 0.6889 - val_precision_4: 0.9369 - val_recall_4: 0.9204 - learning_rate: 5.0000e-04
# Epoch 32/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8795 - loss: 0.7791 - precision_4: 0.8411 - recall_4: 0.8893 - val_accuracy: 0.9224 - val_loss: 0.6556 - val_precision_4: 0.9273 - val_recall_4: 0.9027 - learning_rate: 5.0000e-04
# Epoch 33/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8986 - loss: 0.7254 - precision_4: 0.8374 - recall_4: 0.9378 - val_accuracy: 0.9306 - val_loss: 0.6543 - val_precision_4: 0.9444 - val_recall_4: 0.9027 - learning_rate: 5.0000e-04
# Epoch 34/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9165 - loss: 0.6540 - precision_4: 0.8987 - recall_4: 0.9206 - val_accuracy: 0.9429 - val_loss: 0.6803 - val_precision_4: 0.9901 - val_recall_4: 0.8850 - learning_rate: 5.0000e-04
# Epoch 35/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9031 - loss: 0.6421 - precision_4: 0.9188 - recall_4: 0.8779 - val_accuracy: 0.9143 - val_loss: 0.6529 - val_precision_4: 0.9510 - val_recall_4: 0.8584 - learning_rate: 5.0000e-04
# Epoch 36/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9188 - loss: 0.6165 - precision_4: 0.9036 - recall_4: 0.9212 - val_accuracy: 0.9143 - val_loss: 0.5639 - val_precision_4: 0.9259 - val_recall_4: 0.8850 - learning_rate: 5.0000e-04
# Epoch 37/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9459 - loss: 0.5452 - precision_4: 0.9342 - recall_4: 0.9446 - val_accuracy: 0.9061 - val_loss: 0.5924 - val_precision_4: 0.9688 - val_recall_4: 0.8230 - learning_rate: 5.0000e-04
# Epoch 38/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9290 - loss: 0.5720 - precision_4: 0.9266 - recall_4: 0.9174 - val_accuracy: 0.9306 - val_loss: 0.5436 - val_precision_4: 0.9444 - val_recall_4: 0.9027 - learning_rate: 5.0000e-04
# Epoch 39/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9104 - loss: 0.6012 - precision_4: 0.8924 - recall_4: 0.9119 - val_accuracy: 0.9429 - val_loss: 0.5726 - val_precision_4: 0.9626 - val_recall_4: 0.9115 - learning_rate: 5.0000e-04
# Epoch 40/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9252 - loss: 0.5855 - precision_4: 0.9067 - recall_4: 0.9224 - val_accuracy: 0.9265 - val_loss: 0.5708 - val_precision_4: 0.9798 - val_recall_4: 0.8584 - learning_rate: 5.0000e-04
# Epoch 41/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9064 - loss: 0.5789 - precision_4: 0.8956 - recall_4: 0.9024 - val_accuracy: 0.9388 - val_loss: 0.5486 - val_precision_4: 0.9900 - val_recall_4: 0.8761 - learning_rate: 5.0000e-04
# Epoch 42/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9287 - loss: 0.5486 - precision_4: 0.9671 - recall_4: 0.8775 - val_accuracy: 0.9510 - val_loss: 0.4898 - val_precision_4: 1.0000 - val_recall_4: 0.8938 - learning_rate: 2.5000e-04
# Epoch 43/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9542 - loss: 0.4618 - precision_4: 0.9522 - recall_4: 0.9429 - val_accuracy: 0.9306 - val_loss: 0.5309 - val_precision_4: 0.9800 - val_recall_4: 0.8673 - learning_rate: 2.5000e-04
# Epoch 44/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9212 - loss: 0.5360 - precision_4: 0.9068 - recall_4: 0.9121 - val_accuracy: 0.9143 - val_loss: 0.5306 - val_precision_4: 0.9423 - val_recall_4: 0.8673 - learning_rate: 2.5000e-04
# Epoch 45/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9333 - loss: 0.4834 - precision_4: 0.9239 - recall_4: 0.9321 - val_accuracy: 0.9224 - val_loss: 0.4625 - val_precision_4: 0.9273 - val_recall_4: 0.9027 - learning_rate: 2.5000e-04
# Epoch 46/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9412 - loss: 0.4364 - precision_4: 0.9306 - recall_4: 0.9444 - val_accuracy: 0.9224 - val_loss: 0.5139 - val_precision_4: 0.9700 - val_recall_4: 0.8584 - learning_rate: 2.5000e-04
# Epoch 47/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9435 - loss: 0.4163 - precision_4: 0.9327 - recall_4: 0.9432 - val_accuracy: 0.9347 - val_loss: 0.4848 - val_precision_4: 0.9619 - val_recall_4: 0.8938 - learning_rate: 2.5000e-04
# Epoch 48/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9313 - loss: 0.4528 - precision_4: 0.9617 - recall_4: 0.8969 - val_accuracy: 0.9306 - val_loss: 0.4323 - val_precision_4: 0.9615 - val_recall_4: 0.8850 - learning_rate: 2.5000e-04
# Epoch 49/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9470 - loss: 0.4261 - precision_4: 0.9471 - recall_4: 0.9393 - val_accuracy: 0.8939 - val_loss: 0.6267 - val_precision_4: 0.8655 - val_recall_4: 0.9115 - learning_rate: 2.5000e-04
# Epoch 50/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9538 - loss: 0.3899 - precision_4: 0.9506 - recall_4: 0.9495 - val_accuracy: 0.9265 - val_loss: 0.4444 - val_precision_4: 0.9524 - val_recall_4: 0.8850 - learning_rate: 2.5000e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9526 - loss: 0.3850 - precision_4: 0.9916 - recall_4: 0.9394
# Test Loss: 0.3764, Test Accuracy: 0.9627, Test Precision: 0.9811, Test Recall: 0.9369
# Training stopped at Epoch: 0, Time Taken: 29.65 sec

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

plt.figure(figsize=(12, 4))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       130
#            1       0.98      0.94      0.96       111
#
#     accuracy                           0.96       241
#    macro avg       0.96      0.96      0.96       241
# weighted avg       0.96      0.96      0.96       241

# %%
model.save("KmeansHistogramYellow.keras")
