# %% [markdown]
# ## MODEL USING HISTOGRAM

# %%
import os
import time
import numpy as np
import io
import cv2
import pandas as pd
from sklearn.utils import shuffle
from sklearn.cluster import KMeans
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall

# %%
def extract_l_b_features(image, bins=50, scale=0.8):
    lab_image = cv2.cvtColor(image.astype(np.uint8), cv2.COLOR_RGB2LAB)
    
    lightness = lab_image[:, :, 0].astype(np.float32)  
    b_channel = lab_image[:, :, 2].astype(np.float32)  

    # Min-Max Normalization
    lightness = (lightness - lightness.min()) / (lightness.max() - lightness.min()) * scale
    b_channel = (b_channel - b_channel.min()) / (b_channel.max() - b_channel.min())

    # Compute Histograms
    l_hist = np.histogram(lightness, bins=bins, range=(0, 1), density=True)[0]
    b_hist = np.histogram(b_channel, bins=bins, range=(0, 1), density=True)[0]

    return np.concatenate([l_hist, b_hist])



def load_images_and_labels(folder, label, bins=10):
    images = []
    for file in os.listdir(folder):
        image_path = os.path.join(folder, file)
        image = tf.keras.utils.img_to_array(tf.keras.utils.load_img(image_path))
        color_features = extract_l_b_features(image, bins)
        images.append(color_features.reshape(1, -1))
    labels = [label] * len(images)
    return np.vstack(images), np.array(labels)




train_jaundiced_images, train_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/train", 1
    )
train_healthy_images, train_healthy_labels = load_images_and_labels(
    "./new/Normal Class/train", 0
    )

X_train = np.vstack((train_jaundiced_images, train_healthy_images))
y_train = np.hstack((train_jaundiced_labels, train_healthy_labels))

X_train, y_train = shuffle(X_train, y_train, random_state=1)

test_jaundiced_images, test_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/test", 1
    )
test_healthy_images, test_healthy_labels = load_images_and_labels(
    "./new/Normal Class/test", 0
    )

X_test = np.vstack((test_jaundiced_images, test_healthy_images))
y_test = np.hstack((test_jaundiced_labels, test_healthy_labels))

val_jaundiced_images, val_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/validate", 1
    )
val_healthy_images, val_healthy_labels = load_images_and_labels(
    "./new/Normal Class/validate", 0
    )

X_val = np.vstack((val_jaundiced_images, val_healthy_images))
y_val = np.hstack((val_jaundiced_labels, val_healthy_labels))

print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Jaundiced images shape:", train_jaundiced_images.shape)
print("Healthy images shape:", train_healthy_images.shape)
print("X_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
#print("First 5 rows of X_train:", X_train[:5])
# Out:
# Test data shape: (241, 20)
# Validation data shape: (245, 20)
# Jaundiced images shape: (334, 20)
# Healthy images shape: (392, 20)
# X_train shape: (726, 20)
# X_train dtype: float64

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (726, 20)
# X_test shape: (241, 20)
# X_val shape: (245, 20)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)    
X_val = scaler.transform(X_val)

# %%
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.01), input_dim=X_train.shape[1]),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, kernel_regularizer=l2(0.01)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='sigmoid')
])
# Out:
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

# Callbacks Early Stopping and Reduce LR on Plateau
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=7, restore_best_weights=True)  
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

#Training
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_scheduler]
)

elapsed_time = time.time() - start_time

# Evaluate Model
loss, accuracy, precision, recall = model.evaluate(X_test, y_test)
stopped_epoch = early_stopping.stopped_epoch

print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}, Test Precision: {precision:.4f}, Test Recall: {recall:.4f}")
print(f"Training stopped at Epoch: {stopped_epoch}, Time Taken: {elapsed_time:.2f} sec")
# Out:
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.6672 - loss: 5.6343 - precision: 0.6331 - recall: 0.6676 - val_accuracy: 0.7959 - val_loss: 5.3006 - val_precision: 0.9091 - val_recall: 0.6195 - learning_rate: 5.0000e-04
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7914 - loss: 5.1192 - precision: 0.7550 - recall: 0.7858 - val_accuracy: 0.7592 - val_loss: 4.8943 - val_precision: 0.9821 - val_recall: 0.4867 - learning_rate: 5.0000e-04
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7868 - loss: 4.7944 - precision: 0.8275 - recall: 0.7341 - val_accuracy: 0.8327 - val_loss: 4.4574 - val_precision: 0.9615 - val_recall: 0.6637 - learning_rate: 5.0000e-04
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8397 - loss: 4.3960 - precision: 0.8531 - recall: 0.7984 - val_accuracy: 0.8082 - val_loss: 4.1100 - val_precision: 0.8367 - val_recall: 0.7257 - learning_rate: 5.0000e-04
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8238 - loss: 4.0649 - precision: 0.8101 - recall: 0.8151 - val_accuracy: 0.8612 - val_loss: 3.7530 - val_precision: 0.8835 - val_recall: 0.8053 - learning_rate: 5.0000e-04
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8308 - loss: 3.7601 - precision: 0.7869 - recall: 0.8465 - val_accuracy: 0.8490 - val_loss: 3.5002 - val_precision: 0.9043 - val_recall: 0.7522 - learning_rate: 5.0000e-04
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8480 - loss: 3.4029 - precision: 0.8588 - recall: 0.8114 - val_accuracy: 0.9061 - val_loss: 3.1214 - val_precision: 0.9500 - val_recall: 0.8407 - learning_rate: 5.0000e-04
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8493 - loss: 3.1679 - precision: 0.7943 - recall: 0.8639 - val_accuracy: 0.8735 - val_loss: 2.8982 - val_precision: 0.9457 - val_recall: 0.7699 - learning_rate: 5.0000e-04
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8514 - loss: 2.9255 - precision: 0.8377 - recall: 0.8346 - val_accuracy: 0.8367 - val_loss: 2.7719 - val_precision: 0.8687 - val_recall: 0.7611 - learning_rate: 5.0000e-04
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8696 - loss: 2.6206 - precision: 0.9025 - recall: 0.8170 - val_accuracy: 0.9020 - val_loss: 2.4694 - val_precision: 0.9588 - val_recall: 0.8230 - learning_rate: 5.0000e-04
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8355 - loss: 2.4948 - precision: 0.8327 - recall: 0.8083 - val_accuracy: 0.8490 - val_loss: 2.3401 - val_precision: 0.9318 - val_recall: 0.7257 - learning_rate: 5.0000e-04
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8789 - loss: 2.2829 - precision: 0.8611 - recall: 0.8686 - val_accuracy: 0.8939 - val_loss: 2.0968 - val_precision: 0.9394 - val_recall: 0.8230 - learning_rate: 5.0000e-04
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8560 - loss: 2.0894 - precision: 0.8496 - recall: 0.8286 - val_accuracy: 0.8898 - val_loss: 1.9379 - val_precision: 0.9216 - val_recall: 0.8319 - learning_rate: 5.0000e-04
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8683 - loss: 1.9398 - precision: 0.8238 - recall: 0.8962 - val_accuracy: 0.8816 - val_loss: 1.7869 - val_precision: 0.9375 - val_recall: 0.7965 - learning_rate: 5.0000e-04
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8496 - loss: 1.8877 - precision: 0.8096 - recall: 0.8511 - val_accuracy: 0.9061 - val_loss: 1.6422 - val_precision: 0.9500 - val_recall: 0.8407 - learning_rate: 5.0000e-04
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8725 - loss: 1.6950 - precision: 0.8954 - recall: 0.8415 - val_accuracy: 0.8857 - val_loss: 1.6076 - val_precision: 0.9570 - val_recall: 0.7876 - learning_rate: 5.0000e-04
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8689 - loss: 1.5706 - precision: 0.8739 - recall: 0.8458 - val_accuracy: 0.9143 - val_loss: 1.4505 - val_precision: 0.9340 - val_recall: 0.8761 - learning_rate: 5.0000e-04
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9125 - loss: 1.4043 - precision: 0.9005 - recall: 0.9077 - val_accuracy: 0.8816 - val_loss: 1.4226 - val_precision: 0.8889 - val_recall: 0.8496 - learning_rate: 5.0000e-04
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8913 - loss: 1.3603 - precision: 0.8845 - recall: 0.8803 - val_accuracy: 0.8694 - val_loss: 1.3425 - val_precision: 0.8785 - val_recall: 0.8319 - learning_rate: 5.0000e-04
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8520 - loss: 1.3631 - precision: 0.8853 - recall: 0.8049 - val_accuracy: 0.8980 - val_loss: 1.2241 - val_precision: 0.8860 - val_recall: 0.8938 - learning_rate: 5.0000e-04
# Epoch 21/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8965 - loss: 1.2010 - precision: 0.8981 - recall: 0.8719 - val_accuracy: 0.9102 - val_loss: 1.1744 - val_precision: 0.9333 - val_recall: 0.8673 - learning_rate: 5.0000e-04
# Epoch 22/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8915 - loss: 1.1724 - precision: 0.8658 - recall: 0.9008 - val_accuracy: 0.9020 - val_loss: 1.1350 - val_precision: 0.9238 - val_recall: 0.8584 - learning_rate: 5.0000e-04
# Epoch 23/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9165 - loss: 1.0586 - precision: 0.9228 - recall: 0.9044 - val_accuracy: 0.9061 - val_loss: 1.0667 - val_precision: 0.9091 - val_recall: 0.8850 - learning_rate: 5.0000e-04
# Epoch 24/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8943 - loss: 1.0493 - precision: 0.9012 - recall: 0.8758 - val_accuracy: 0.8857 - val_loss: 1.0496 - val_precision: 0.9126 - val_recall: 0.8319 - learning_rate: 5.0000e-04
# Epoch 25/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9090 - loss: 1.0088 - precision: 0.9161 - recall: 0.8773 - val_accuracy: 0.9184 - val_loss: 0.9749 - val_precision: 0.9115 - val_recall: 0.9115 - learning_rate: 5.0000e-04
# Epoch 26/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9000 - loss: 0.9259 - precision: 0.8995 - recall: 0.8851 - val_accuracy: 0.8776 - val_loss: 1.0152 - val_precision: 0.8952 - val_recall: 0.8319 - learning_rate: 5.0000e-04
# Epoch 27/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8962 - loss: 0.9719 - precision: 0.8902 - recall: 0.8881 - val_accuracy: 0.9020 - val_loss: 0.9080 - val_precision: 0.9238 - val_recall: 0.8584 - learning_rate: 5.0000e-04
# Epoch 28/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8640 - loss: 0.9631 - precision: 0.8254 - recall: 0.8641 - val_accuracy: 0.9184 - val_loss: 0.8512 - val_precision: 0.9115 - val_recall: 0.9115 - learning_rate: 5.0000e-04
# Epoch 29/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9003 - loss: 0.8771 - precision: 0.8589 - recall: 0.9204 - val_accuracy: 0.8898 - val_loss: 0.8372 - val_precision: 0.8707 - val_recall: 0.8938 - learning_rate: 5.0000e-04
# Epoch 30/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8662 - loss: 0.9060 - precision: 0.7972 - recall: 0.9064 - val_accuracy: 0.9184 - val_loss: 0.7877 - val_precision: 0.9429 - val_recall: 0.8761 - learning_rate: 5.0000e-04
# Epoch 31/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9063 - loss: 0.8112 - precision: 0.8610 - recall: 0.9221 - val_accuracy: 0.8653 - val_loss: 0.8759 - val_precision: 0.8704 - val_recall: 0.8319 - learning_rate: 5.0000e-04
# Epoch 32/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9057 - loss: 0.7733 - precision: 0.9030 - recall: 0.9056 - val_accuracy: 0.8776 - val_loss: 0.8574 - val_precision: 0.8739 - val_recall: 0.8584 - learning_rate: 5.0000e-04
# Epoch 33/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8898 - loss: 0.7750 - precision: 0.8597 - recall: 0.8857 - val_accuracy: 0.8816 - val_loss: 0.7591 - val_precision: 0.8889 - val_recall: 0.8496 - learning_rate: 5.0000e-04
# Epoch 34/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9088 - loss: 0.7140 - precision: 0.9065 - recall: 0.8970 - val_accuracy: 0.9102 - val_loss: 0.7278 - val_precision: 0.9505 - val_recall: 0.8496 - learning_rate: 5.0000e-04
# Epoch 35/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9010 - loss: 0.7024 - precision: 0.8886 - recall: 0.8892 - val_accuracy: 0.9224 - val_loss: 0.6451 - val_precision: 0.9434 - val_recall: 0.8850 - learning_rate: 5.0000e-04
# Epoch 36/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8889 - loss: 0.6980 - precision: 0.8545 - recall: 0.8954 - val_accuracy: 0.8816 - val_loss: 0.7811 - val_precision: 0.8962 - val_recall: 0.8407 - learning_rate: 5.0000e-04
# Epoch 37/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8967 - loss: 0.6738 - precision: 0.8820 - recall: 0.8848 - val_accuracy: 0.8939 - val_loss: 0.7076 - val_precision: 0.8991 - val_recall: 0.8673 - learning_rate: 5.0000e-04
# Epoch 38/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8781 - loss: 0.6605 - precision: 0.8557 - recall: 0.8895 - val_accuracy: 0.9102 - val_loss: 0.6219 - val_precision: 0.9505 - val_recall: 0.8496 - learning_rate: 5.0000e-04
# Epoch 39/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9406 - loss: 0.5579 - precision: 0.9560 - recall: 0.9154 - val_accuracy: 0.8857 - val_loss: 0.6662 - val_precision: 0.8571 - val_recall: 0.9027 - learning_rate: 5.0000e-04
# Epoch 40/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9148 - loss: 0.5778 - precision: 0.9060 - recall: 0.9092 - val_accuracy: 0.9184 - val_loss: 0.6084 - val_precision: 0.9189 - val_recall: 0.9027 - learning_rate: 5.0000e-04
# Epoch 41/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9293 - loss: 0.5691 - precision: 0.9302 - recall: 0.9122 - val_accuracy: 0.9061 - val_loss: 0.6345 - val_precision: 0.9327 - val_recall: 0.8584 - learning_rate: 5.0000e-04
# Epoch 42/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9198 - loss: 0.5687 - precision: 0.9123 - recall: 0.9124 - val_accuracy: 0.8776 - val_loss: 0.6484 - val_precision: 0.9278 - val_recall: 0.7965 - learning_rate: 5.0000e-04
# Epoch 43/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.5450 - precision: 0.9149 - recall: 0.9276 - val_accuracy: 0.9265 - val_loss: 0.6083 - val_precision: 0.9524 - val_recall: 0.8850 - learning_rate: 5.0000e-04
# Epoch 44/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9096 - loss: 0.5720 - precision: 0.9007 - recall: 0.9159 - val_accuracy: 0.9265 - val_loss: 0.5408 - val_precision: 0.9439 - val_recall: 0.8938 - learning_rate: 2.5000e-04
# Epoch 45/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9147 - loss: 0.5011 - precision: 0.9197 - recall: 0.8944 - val_accuracy: 0.9184 - val_loss: 0.5195 - val_precision: 0.9429 - val_recall: 0.8761 - learning_rate: 2.5000e-04
# Epoch 46/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9154 - loss: 0.5097 - precision: 0.9287 - recall: 0.8928 - val_accuracy: 0.9469 - val_loss: 0.4820 - val_precision: 0.9902 - val_recall: 0.8938 - learning_rate: 2.5000e-04
# Epoch 47/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.4699 - precision: 0.9304 - recall: 0.9189 - val_accuracy: 0.8898 - val_loss: 0.5161 - val_precision: 0.9216 - val_recall: 0.8319 - learning_rate: 2.5000e-04
# Epoch 48/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9370 - loss: 0.4579 - precision: 0.9473 - recall: 0.9208 - val_accuracy: 0.9469 - val_loss: 0.4504 - val_precision: 0.9545 - val_recall: 0.9292 - learning_rate: 2.5000e-04
# Epoch 49/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 0.4175 - precision: 0.9652 - recall: 0.9449 - val_accuracy: 0.9224 - val_loss: 0.5444 - val_precision: 0.9196 - val_recall: 0.9115 - learning_rate: 2.5000e-04
# Epoch 50/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9249 - loss: 0.4557 - precision: 0.9183 - recall: 0.9250 - val_accuracy: 0.9347 - val_loss: 0.4425 - val_precision: 0.9802 - val_recall: 0.8761 - learning_rate: 2.5000e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9449 - loss: 0.4564 - precision: 0.9936 - recall: 0.9282
# Test Loss: 0.4124, Test Accuracy: 0.9585, Test Precision: 0.9810, Test Recall: 0.9279
# Training stopped at Epoch: 0, Time Taken: 26.64 sec

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

plt.figure(figsize=(12, 4))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Acc
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        65
#            1       1.00      0.95      0.97        55
#
#     accuracy                           0.97       120
#    macro avg       0.98      0.97      0.97       120
# weighted avg       0.98      0.97      0.97       120
