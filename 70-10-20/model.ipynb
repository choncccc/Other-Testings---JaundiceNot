# %% [markdown]
# ## MODEL
# * Install muna ako NVIDIA CUDA tas cuDNN para di sumabog PC

# %%
import os
import time
import numpy as np
import io
import pandas as pd
from sklearn.utils import shuffle
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.utils import load_img, img_to_array

# %%
def load_images_and_labels(folder, label, target_size=(200, 200)):
    images = []
    for file in os.listdir(folder):
        image_path = os.path.join(folder, file)
        image = tf.keras.utils.load_img(image_path, target_size=target_size) 
        image_array = tf.keras.utils.img_to_array(image)
        images.append(image_array.flatten())  
    labels = [label] * len(images)
    return np.array(images), np.array(labels)

train_jaundiced_images, train_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class1/train", 1)
train_healthy_images, train_healthy_labels = load_images_and_labels("./new/Normal Class1/train", 0)

X_train = np.vstack((train_jaundiced_images, train_healthy_images))
y_train = np.hstack((train_jaundiced_labels, train_healthy_labels))

X_train, y_train = shuffle(X_train, y_train, random_state=1)

test_jaundiced_images, test_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class1/test", 1)
test_healthy_images, test_healthy_labels = load_images_and_labels("./new/Normal Class1/test", 0)

val_jaundiced_images, val_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class1/validate", 1)
val_healthy_images, val_healthy_labels = load_images_and_labels("./new/Normal Class1/validate", 0)

X_test = np.vstack((test_jaundiced_images, test_healthy_images))
y_test = np.hstack((test_jaundiced_labels, test_healthy_labels))

X_val = np.vstack((val_jaundiced_images, val_healthy_images))
y_val = np.hstack((val_jaundiced_labels, val_healthy_labels))


# Print dataset details for debugging
print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Jaundiced images shape:", train_jaundiced_images.shape)
print("Healthy images shape:", train_healthy_images.shape)
print("X_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
print("First 5 rows of X_train:", X_train[:5])
# Out:
# Test data shape: (39, 120000)
# Validation data shape: (43, 120000)
# Jaundiced images shape: (55, 120000)
# Healthy images shape: (65, 120000)
# X_train shape: (120, 120000)
# X_train dtype: float32
# First 5 rows of X_train: [[238. 201. 175. ... 153. 117.  93.]
#  [168. 114.  90. ... 155. 117.  96.]
#  [ 46.  21.   1. ... 220. 165. 135.]
#  [255. 216. 200. ... 212. 167. 146.]
#  [217. 184. 177. ... 107.  87.  86.]]

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (120, 120000)
# X_test shape: (39, 120000)
# X_val shape: (43, 120000)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Fit 
X_test = scaler.transform(X_test)       # Transform test data (images only with no annotations but with features)
X_val = scaler.transform(X_val)

# %%
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.01), input_dim=X_train.shape[1]),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, kernel_regularizer=l2(0.01)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

# Callbacks Early Stopping and Reduce LR on Plateau
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=7, restore_best_weights=True)  
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

#Training
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_scheduler]
)

elapsed_time = time.time() - start_time

# Evaluate Model
loss, accuracy, precision, recall = model.evaluate(X_test, y_test)
stopped_epoch = early_stopping.stopped_epoch

print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}, Test Precision: {precision:.4f}, Recall: {recall:.4f}")
print(f"Training stopped at Epoch: {stopped_epoch}, Time Taken: {elapsed_time:.2f} sec")
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 739ms/step - accuracy: 0.4527 - loss: 16.1681 - precision_1: 0.3980 - recall_1: 0.4461 - val_accuracy: 0.6744 - val_loss: 17.7110 - val_precision_1: 0.6071 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 704ms/step - accuracy: 0.7450 - loss: 16.3565 - precision_1: 0.7293 - recall_1: 0.7439 - val_accuracy: 0.8372 - val_loss: 16.7831 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 645ms/step - accuracy: 0.7992 - loss: 16.7103 - precision_1: 0.7937 - recall_1: 0.7959 - val_accuracy: 0.9070 - val_loss: 16.7574 - val_precision_1: 0.9000 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 654ms/step - accuracy: 0.9075 - loss: 16.6774 - precision_1: 0.8880 - recall_1: 0.9053 - val_accuracy: 0.9070 - val_loss: 16.5482 - val_precision_1: 0.9000 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 729ms/step - accuracy: 0.8773 - loss: 16.5389 - precision_1: 0.8588 - recall_1: 0.8406 - val_accuracy: 0.8372 - val_loss: 16.1691 - val_precision_1: 0.8421 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 725ms/step - accuracy: 0.9260 - loss: 16.0792 - precision_1: 0.9048 - recall_1: 0.9366 - val_accuracy: 0.8140 - val_loss: 15.7087 - val_precision_1: 0.8333 - val_recall_1: 0.7500 - learning_rate: 5.0000e-04
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 685ms/step - accuracy: 0.9306 - loss: 15.4752 - precision_1: 0.9793 - recall_1: 0.8744 - val_accuracy: 0.7907 - val_loss: 15.0919 - val_precision_1: 0.7895 - val_recall_1: 0.7500 - learning_rate: 5.0000e-04
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 579ms/step - accuracy: 0.9442 - loss: 14.8000 - precision_1: 0.9345 - recall_1: 0.9521 - val_accuracy: 0.7907 - val_loss: 14.4368 - val_precision_1: 0.7895 - val_recall_1: 0.7500 - learning_rate: 5.0000e-04
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9448 - loss: 14.1080 - precision_1: 0.9467 - recall_1: 0.9402 - val_accuracy: 0.8372 - val_loss: 13.7045 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 577ms/step - accuracy: 0.9129 - loss: 13.4374 - precision_1: 0.9097 - recall_1: 0.8942 - val_accuracy: 0.8140 - val_loss: 13.1034 - val_precision_1: 0.8000 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 566ms/step - accuracy: 0.9337 - loss: 12.6941 - precision_1: 0.9411 - recall_1: 0.9263 - val_accuracy: 0.8605 - val_loss: 12.3552 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9565 - loss: 12.0069 - precision_1: 0.9501 - recall_1: 0.9567 - val_accuracy: 0.8372 - val_loss: 11.7302 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 569ms/step - accuracy: 1.0000 - loss: 11.3417 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8140 - val_loss: 11.2072 - val_precision_1: 0.8000 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9767 - loss: 10.8089 - precision_1: 1.0000 - recall_1: 0.9487 - val_accuracy: 0.7907 - val_loss: 10.7389 - val_precision_1: 0.7895 - val_recall_1: 0.7500 - learning_rate: 5.0000e-04
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9773 - loss: 10.2381 - precision_1: 0.9925 - recall_1: 0.9585 - val_accuracy: 0.7907 - val_loss: 10.2477 - val_precision_1: 0.7619 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 566ms/step - accuracy: 0.9394 - loss: 9.7667 - precision_1: 0.9645 - recall_1: 0.9169 - val_accuracy: 0.8140 - val_loss: 9.6869 - val_precision_1: 0.7727 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.9765 - loss: 9.2478 - precision_1: 1.0000 - recall_1: 0.9456 - val_accuracy: 0.8140 - val_loss: 9.2762 - val_precision_1: 0.7727 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9860 - loss: 8.7957 - precision_1: 0.9883 - recall_1: 0.9822 - val_accuracy: 0.7907 - val_loss: 8.9038 - val_precision_1: 0.7391 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9946 - loss: 8.3956 - precision_1: 1.0000 - recall_1: 0.9883 - val_accuracy: 0.7674 - val_loss: 8.5077 - val_precision_1: 0.7273 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 574ms/step - accuracy: 0.9915 - loss: 8.0219 - precision_1: 0.9820 - recall_1: 1.0000 - val_accuracy: 0.7209 - val_loss: 8.1857 - val_precision_1: 0.6818 - val_recall_1: 0.7500 - learning_rate: 5.0000e-04
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.9915 - loss: 7.6661 - precision_1: 0.9817 - recall_1: 1.0000 - val_accuracy: 0.8140 - val_loss: 7.7491 - val_precision_1: 0.7500 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 1.0000 - loss: 7.3231 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8140 - val_loss: 7.4141 - val_precision_1: 0.7727 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9767 - loss: 7.0360 - precision_1: 1.0000 - recall_1: 0.9557 - val_accuracy: 0.7907 - val_loss: 7.1694 - val_precision_1: 0.7619 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 1.0000 - loss: 6.7364 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8605 - val_loss: 6.7913 - val_precision_1: 0.8889 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 568ms/step - accuracy: 0.9915 - loss: 6.4525 - precision_1: 0.9816 - recall_1: 1.0000 - val_accuracy: 0.9070 - val_loss: 6.4802 - val_precision_1: 0.9444 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 1.0000 - loss: 6.1986 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8837 - val_loss: 6.2155 - val_precision_1: 0.8947 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9946 - loss: 5.9818 - precision_1: 0.9885 - recall_1: 1.0000 - val_accuracy: 0.8837 - val_loss: 6.0231 - val_precision_1: 0.8947 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 577ms/step - accuracy: 0.9967 - loss: 5.7391 - precision_1: 1.0000 - recall_1: 0.9927 - val_accuracy: 0.8140 - val_loss: 5.9005 - val_precision_1: 0.8000 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 566ms/step - accuracy: 0.9915 - loss: 5.5247 - precision_1: 1.0000 - recall_1: 0.9821 - val_accuracy: 0.8605 - val_loss: 5.6497 - val_precision_1: 0.8182 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 566ms/step - accuracy: 0.9852 - loss: 5.3509 - precision_1: 0.9661 - recall_1: 1.0000 - val_accuracy: 0.9070 - val_loss: 5.4247 - val_precision_1: 0.9000 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9946 - loss: 5.1604 - precision_1: 0.9883 - recall_1: 1.0000 - val_accuracy: 0.8837 - val_loss: 5.2442 - val_precision_1: 0.8571 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.9456 - loss: 5.0809 - precision_1: 0.9849 - recall_1: 0.9140 - val_accuracy: 0.8372 - val_loss: 5.1213 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9967 - loss: 4.8593 - precision_1: 1.0000 - recall_1: 0.9927 - val_accuracy: 0.8605 - val_loss: 4.9761 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9804 - loss: 4.7518 - precision_1: 0.9762 - recall_1: 0.9807 - val_accuracy: 0.8605 - val_loss: 4.8905 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9967 - loss: 4.6590 - precision_1: 1.0000 - recall_1: 0.9927 - val_accuracy: 0.8605 - val_loss: 4.8012 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 553ms/step - accuracy: 0.9852 - loss: 4.5335 - precision_1: 0.9689 - recall_1: 1.0000 - val_accuracy: 0.8372 - val_loss: 4.8123 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9798 - loss: 4.4251 - precision_1: 0.9596 - recall_1: 1.0000 - val_accuracy: 0.8605 - val_loss: 4.6526 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 0.9765 - loss: 4.3460 - precision_1: 0.9878 - recall_1: 0.9648 - val_accuracy: 0.8837 - val_loss: 4.4738 - val_precision_1: 0.8947 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9806 - loss: 4.1941 - precision_1: 0.9770 - recall_1: 0.9824 - val_accuracy: 0.8605 - val_loss: 4.2939 - val_precision_1: 0.8889 - val_recall_1: 0.8000 - learning_rate: 5.0000e-04
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9946 - loss: 4.0312 - precision_1: 1.0000 - recall_1: 0.9882 - val_accuracy: 0.8837 - val_loss: 4.1950 - val_precision_1: 0.8947 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 567ms/step - accuracy: 0.9563 - loss: 3.9940 - precision_1: 0.9140 - recall_1: 0.9927 - val_accuracy: 0.8837 - val_loss: 4.1072 - val_precision_1: 0.8947 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9806 - loss: 3.8630 - precision_1: 0.9772 - recall_1: 0.9828 - val_accuracy: 0.8605 - val_loss: 3.9893 - val_precision_1: 0.8500 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9892 - loss: 3.7312 - precision_1: 1.0000 - recall_1: 0.9762 - val_accuracy: 0.8837 - val_loss: 3.8856 - val_precision_1: 0.8571 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 1.0000 - loss: 3.6106 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.9070 - val_loss: 3.7545 - val_precision_1: 0.9000 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9967 - loss: 3.5225 - precision_1: 1.0000 - recall_1: 0.9927 - val_accuracy: 0.8837 - val_loss: 3.6729 - val_precision_1: 0.8571 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 0.9892 - loss: 3.4453 - precision_1: 1.0000 - recall_1: 0.9766 - val_accuracy: 0.8372 - val_loss: 3.6202 - val_precision_1: 0.7826 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 1.0000 - loss: 3.3174 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8140 - val_loss: 3.5972 - val_precision_1: 0.7727 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9967 - loss: 3.2451 - precision_1: 0.9929 - recall_1: 1.0000 - val_accuracy: 0.8372 - val_loss: 3.4966 - val_precision_1: 0.8095 - val_recall_1: 0.8500 - learning_rate: 5.0000e-04
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 575ms/step - accuracy: 1.0000 - loss: 3.1567 - precision_1: 1.0000 - recall_1: 1.0000 - val_accuracy: 0.8605 - val_loss: 3.3977 - val_precision_1: 0.8182 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/step - accuracy: 0.9946 - loss: 3.0859 - precision_1: 1.0000 - recall_1: 0.9882 - val_accuracy: 0.8837 - val_loss: 3.2819 - val_precision_1: 0.8571 - val_recall_1: 0.9000 - learning_rate: 5.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8283 - loss: 3.3373 - precision_1: 0.7886 - recall_1: 0.8889
# Test Loss: 3.3352, Test Accuracy: 0.8205, Test Precision: 0.7619, Recall: 0.8889
# Training stopped at Epoch: 0, Time Taken: 118.11 sec

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Plot CM
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Loss and Accuracy Plots
plt.figure(figsize=(12, 4))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        21
#            1       0.76      0.89      0.82        18
#
#     accuracy                           0.82        39
#    macro avg       0.83      0.83      0.82        39
# weighted avg       0.83      0.82      0.82        39

# %%
#model.save("Jaundice_ClassifierV1.keras")
