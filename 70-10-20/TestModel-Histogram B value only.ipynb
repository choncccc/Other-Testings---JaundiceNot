# %% [markdown]
# ## MODEL USING HISTOGRAM

# %%
import os
import time
import numpy as np
import io
import cv2
import pandas as pd
from sklearn.utils import shuffle
from sklearn.cluster import KMeans
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.utils import load_img, img_to_array

# %%
def extract_b_channel_features(image, bins=50):
    lab_image = cv2.cvtColor(image.astype(np.uint8), cv2.COLOR_RGB2LAB)
    b_channel = lab_image[:, :, 2]

    b_channel = (b_channel - b_channel.min()) / (b_channel.max() - b_channel.min())
    b_hist = np.histogram(b_channel, bins=bins, range=(0, 1), density=True)[0]

    return b_hist

def load_images_and_labels(folder, label, bins=10):
    images = []
    for file in os.listdir(folder):
        image_path = os.path.join(folder, file)
        image = tf.keras.utils.img_to_array(tf.keras.utils.load_img(image_path))
        color_features = extract_b_channel_features(image, bins)
        images.append(color_features.reshape(1, -1))
    labels = [label] * len(images)
    return np.vstack(images), np.array(labels)

# Load dataset
train_jaundiced_images, train_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/train", 1
    )
train_healthy_images, train_healthy_labels = load_images_and_labels(
    "./new/Normal Class/train", 0
    )

X_train = np.vstack((train_jaundiced_images, train_healthy_images))
y_train = np.hstack((train_jaundiced_labels, train_healthy_labels))

X_train, y_train = shuffle(X_train, y_train, random_state=1)

test_jaundiced_images, test_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/test", 1
    )
test_healthy_images, test_healthy_labels = load_images_and_labels(
    "./new/Normal Class/test", 0
    )

X_test = np.vstack((test_jaundiced_images, test_healthy_images))
y_test = np.hstack((test_jaundiced_labels, test_healthy_labels))

val_jaundiced_images, val_jaundiced_labels = load_images_and_labels(
    "./new/Jaundiced Class/validate", 1
    #"./validate/validate J", 1
    )
val_healthy_images, val_healthy_labels = load_images_and_labels(
    "./new/Normal Class/validate", 0
    )

X_val = np.vstack((val_jaundiced_images, val_healthy_images))
y_val = np.hstack((val_jaundiced_labels, val_healthy_labels))

# Print dataset details for debugging
print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Jaundiced images shape:", train_jaundiced_images.shape)
print("Healthy images shape:", train_healthy_images.shape)
print("X_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
print("First 5 rows of X_train:", X_train[:5])
# Out:
# Test data shape: (120, 10)
# Validation data shape: (245, 10)
# Jaundiced images shape: (390, 10)
# Healthy images shape: (457, 10)
# X_train shape: (847, 10)
# X_train dtype: float64
# First 5 rows of X_train: [[1.45000e-02 7.97500e-02 1.94000e-01 6.94750e-01 1.39500e+00 2.44050e+00
#   3.95200e+00 1.04575e+00 1.75250e-01 8.50000e-03]
#  [4.35000e-02 1.03350e+00 2.23250e-01 1.52875e+00 3.39325e+00 2.74550e+00
#   5.78500e-01 3.11500e-01 1.22750e-01 1.95000e-02]
#  [1.33825e+00 1.80575e+00 1.49125e+00 2.46650e+00 2.67125e+00 1.84250e-01
#   1.82500e-02 1.30000e-02 9.00000e-03 2.50000e-03]
#  [3.25000e-02 1.37000e-01 4.06750e-01 1.06600e+00 2.72250e+00 2.70175e+00
#   1.55850e+00 1.07100e+00 2.63250e-01 4.07500e-02]
#  [6.75000e-03 1.02500e-02 2.47500e-02 1.51000e-01 2.74000e-01 2.75500e-01
#   6.51750e-01 2.17000e+00 5.79475e+00 6.41250e-01]]

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (847, 10)
# X_test shape: (120, 10)
# X_val shape: (245, 10)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Fit 
X_test = scaler.transform(X_test)       # Transform test data (images only with no annotations but with features)
X_val = scaler.transform(X_val)

# %%
model = Sequential([
    Dense(512, kernel_regularizer=l2(0.01), input_dim=X_train.shape[1]),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, kernel_regularizer=l2(0.01)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, kernel_regularizer=l2(0.005)),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='sigmoid')  # Binary classification
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy', Precision(), Recall()]
)

# Callbacks Early Stopping and Reduce LR on Plateau
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=7, restore_best_weights=True)  
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

#Training
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_scheduler]
)

elapsed_time = time.time() - start_time

# Evaluate Model
loss, accuracy, precision, recall = model.evaluate(X_test, y_test)
stopped_epoch = early_stopping.stopped_epoch

print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}, Test Precision: {precision:.4f}, Test Recall: {recall:.4f}")
print(f"Training stopped at Epoch: {stopped_epoch}, Time Taken: {elapsed_time:.2f} sec")
# Out:
# Epoch 1/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8383 - loss: 0.4649 - precision_6: 0.8234 - recall_6: 0.7954 - val_accuracy: 0.8857 - val_loss: 0.4249 - val_precision_6: 0.8761 - val_recall_6: 0.8761 - learning_rate: 5.0000e-04
# Epoch 2/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8443 - loss: 0.4691 - precision_6: 0.8670 - recall_6: 0.8127 - val_accuracy: 0.8857 - val_loss: 0.4210 - val_precision_6: 0.8632 - val_recall_6: 0.8938 - learning_rate: 5.0000e-04
# Epoch 3/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8787 - loss: 0.4276 - precision_6: 0.8656 - recall_6: 0.8737 - val_accuracy: 0.8694 - val_loss: 0.4619 - val_precision_6: 0.8785 - val_recall_6: 0.8319 - learning_rate: 5.0000e-04
# Epoch 4/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8343 - loss: 0.4592 - precision_6: 0.8271 - recall_6: 0.8066 - val_accuracy: 0.8694 - val_loss: 0.3933 - val_precision_6: 0.8240 - val_recall_6: 0.9115 - learning_rate: 5.0000e-04
# Epoch 5/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8576 - loss: 0.4444 - precision_6: 0.8644 - recall_6: 0.8301 - val_accuracy: 0.8571 - val_loss: 0.4439 - val_precision_6: 0.8679 - val_recall_6: 0.8142 - learning_rate: 5.0000e-04
# Epoch 6/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8507 - loss: 0.5168 - precision_6: 0.8402 - recall_6: 0.8107 - val_accuracy: 0.8898 - val_loss: 0.3986 - val_precision_6: 0.8644 - val_recall_6: 0.9027 - learning_rate: 5.0000e-04
# Epoch 7/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8758 - loss: 0.4171 - precision_6: 0.8745 - recall_6: 0.8586 - val_accuracy: 0.9020 - val_loss: 0.3878 - val_precision_6: 0.9406 - val_recall_6: 0.8407 - learning_rate: 5.0000e-04
# Epoch 8/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8470 - loss: 0.4460 - precision_6: 0.8638 - recall_6: 0.8019 - val_accuracy: 0.8898 - val_loss: 0.4397 - val_precision_6: 0.9135 - val_recall_6: 0.8407 - learning_rate: 5.0000e-04
# Epoch 9/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8514 - loss: 0.4529 - precision_6: 0.8501 - recall_6: 0.8005 - val_accuracy: 0.8694 - val_loss: 0.4265 - val_precision_6: 0.8403 - val_recall_6: 0.8850 - learning_rate: 5.0000e-04
# Epoch 10/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8701 - loss: 0.4131 - precision_6: 0.8456 - recall_6: 0.8694 - val_accuracy: 0.8653 - val_loss: 0.4474 - val_precision_6: 0.8226 - val_recall_6: 0.9027 - learning_rate: 5.0000e-04
# Epoch 11/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8693 - loss: 0.4360 - precision_6: 0.8545 - recall_6: 0.8737 - val_accuracy: 0.8939 - val_loss: 0.4132 - val_precision_6: 0.9143 - val_recall_6: 0.8496 - learning_rate: 2.5000e-04
# Epoch 12/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8683 - loss: 0.4148 - precision_6: 0.8746 - recall_6: 0.8355 - val_accuracy: 0.8980 - val_loss: 0.3976 - val_precision_6: 0.8929 - val_recall_6: 0.8850 - learning_rate: 2.5000e-04
# Epoch 13/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8629 - loss: 0.4121 - precision_6: 0.8690 - recall_6: 0.8207 - val_accuracy: 0.8857 - val_loss: 0.3834 - val_precision_6: 0.8571 - val_recall_6: 0.9027 - learning_rate: 2.5000e-04
# Epoch 14/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8774 - loss: 0.3828 - precision_6: 0.8662 - recall_6: 0.8691 - val_accuracy: 0.8898 - val_loss: 0.3856 - val_precision_6: 0.9057 - val_recall_6: 0.8496 - learning_rate: 2.5000e-04
# Epoch 15/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8812 - loss: 0.4040 - precision_6: 0.8703 - recall_6: 0.8729 - val_accuracy: 0.9102 - val_loss: 0.3618 - val_precision_6: 0.8957 - val_recall_6: 0.9115 - learning_rate: 2.5000e-04
# Epoch 16/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8603 - loss: 0.4311 - precision_6: 0.8688 - recall_6: 0.8317 - val_accuracy: 0.8980 - val_loss: 0.3630 - val_precision_6: 0.9151 - val_recall_6: 0.8584 - learning_rate: 2.5000e-04
# Epoch 17/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8699 - loss: 0.4073 - precision_6: 0.8871 - recall_6: 0.8206 - val_accuracy: 0.9143 - val_loss: 0.3508 - val_precision_6: 0.9107 - val_recall_6: 0.9027 - learning_rate: 2.5000e-04
# Epoch 18/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8650 - loss: 0.3999 - precision_6: 0.8588 - recall_6: 0.8339 - val_accuracy: 0.9184 - val_loss: 0.3473 - val_precision_6: 0.9266 - val_recall_6: 0.8938 - learning_rate: 2.5000e-04
# Epoch 19/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8753 - loss: 0.3718 - precision_6: 0.8550 - recall_6: 0.8728 - val_accuracy: 0.8898 - val_loss: 0.3790 - val_precision_6: 0.9216 - val_recall_6: 0.8319 - learning_rate: 2.5000e-04
# Epoch 20/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8666 - loss: 0.3813 - precision_6: 0.8835 - recall_6: 0.8221 - val_accuracy: 0.9020 - val_loss: 0.3351 - val_precision_6: 0.8938 - val_recall_6: 0.8938 - learning_rate: 2.5000e-04
# Epoch 21/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8983 - loss: 0.3651 - precision_6: 0.9071 - recall_6: 0.8773 - val_accuracy: 0.9143 - val_loss: 0.3284 - val_precision_6: 0.9423 - val_recall_6: 0.8673 - learning_rate: 2.5000e-04
# Epoch 22/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8883 - loss: 0.3555 - precision_6: 0.8882 - recall_6: 0.8592 - val_accuracy: 0.8816 - val_loss: 0.4035 - val_precision_6: 0.8889 - val_recall_6: 0.8496 - learning_rate: 2.5000e-04
# Epoch 23/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8591 - loss: 0.3950 - precision_6: 0.8487 - recall_6: 0.8478 - val_accuracy: 0.9061 - val_loss: 0.3562 - val_precision_6: 0.8947 - val_recall_6: 0.9027 - learning_rate: 2.5000e-04
# Epoch 24/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8703 - loss: 0.3884 - precision_6: 0.8733 - recall_6: 0.8498 - val_accuracy: 0.8980 - val_loss: 0.3516 - val_precision_6: 0.8729 - val_recall_6: 0.9115 - learning_rate: 2.5000e-04
# Epoch 25/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8911 - loss: 0.3610 - precision_6: 0.8534 - recall_6: 0.8983 - val_accuracy: 0.9143 - val_loss: 0.3552 - val_precision_6: 0.9035 - val_recall_6: 0.9115 - learning_rate: 1.2500e-04
# Epoch 26/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8684 - loss: 0.3807 - precision_6: 0.8393 - recall_6: 0.8625 - val_accuracy: 0.9061 - val_loss: 0.3402 - val_precision_6: 0.8879 - val_recall_6: 0.9115 - learning_rate: 1.2500e-04
# Epoch 27/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8618 - loss: 0.3979 - precision_6: 0.8309 - recall_6: 0.8608 - val_accuracy: 0.8939 - val_loss: 0.3348 - val_precision_6: 0.8655 - val_recall_6: 0.9115 - learning_rate: 1.2500e-04
# Epoch 28/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8802 - loss: 0.3781 - precision_6: 0.8511 - recall_6: 0.8804 - val_accuracy: 0.9143 - val_loss: 0.3250 - val_precision_6: 0.9035 - val_recall_6: 0.9115 - learning_rate: 6.2500e-05
# Epoch 29/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9145 - loss: 0.3284 - precision_6: 0.8903 - recall_6: 0.9151 - val_accuracy: 0.9224 - val_loss: 0.3190 - val_precision_6: 0.9123 - val_recall_6: 0.9204 - learning_rate: 6.2500e-05
# Epoch 30/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8745 - loss: 0.4001 - precision_6: 0.9084 - recall_6: 0.8378 - val_accuracy: 0.9184 - val_loss: 0.3246 - val_precision_6: 0.9043 - val_recall_6: 0.9204 - learning_rate: 6.2500e-05
# Epoch 31/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9044 - loss: 0.3135 - precision_6: 0.8985 - recall_6: 0.9000 - val_accuracy: 0.9184 - val_loss: 0.3190 - val_precision_6: 0.8974 - val_recall_6: 0.9292 - learning_rate: 6.2500e-05
# Epoch 32/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8769 - loss: 0.3258 - precision_6: 0.8458 - recall_6: 0.8905 - val_accuracy: 0.9224 - val_loss: 0.3190 - val_precision_6: 0.9123 - val_recall_6: 0.9204 - learning_rate: 6.2500e-05
# Epoch 33/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9034 - loss: 0.3346 - precision_6: 0.9039 - recall_6: 0.8945 - val_accuracy: 0.9184 - val_loss: 0.3138 - val_precision_6: 0.9115 - val_recall_6: 0.9115 - learning_rate: 3.1250e-05
# Epoch 34/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8787 - loss: 0.3413 - precision_6: 0.8446 - recall_6: 0.8942 - val_accuracy: 0.9061 - val_loss: 0.3118 - val_precision_6: 0.8947 - val_recall_6: 0.9027 - learning_rate: 3.1250e-05
# Epoch 35/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9218 - loss: 0.2896 - precision_6: 0.9137 - recall_6: 0.9217 - val_accuracy: 0.9102 - val_loss: 0.3108 - val_precision_6: 0.8957 - val_recall_6: 0.9115 - learning_rate: 3.1250e-05
# Epoch 36/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9236 - loss: 0.2620 - precision_6: 0.9127 - recall_6: 0.9164 - val_accuracy: 0.9224 - val_loss: 0.3062 - val_precision_6: 0.9196 - val_recall_6: 0.9115 - learning_rate: 3.1250e-05
# Epoch 37/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9010 - loss: 0.3373 - precision_6: 0.8930 - recall_6: 0.8892 - val_accuracy: 0.9143 - val_loss: 0.3078 - val_precision_6: 0.9107 - val_recall_6: 0.9027 - learning_rate: 3.1250e-05
# Epoch 38/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8957 - loss: 0.3478 - precision_6: 0.8862 - recall_6: 0.8855 - val_accuracy: 0.9143 - val_loss: 0.3090 - val_precision_6: 0.9035 - val_recall_6: 0.9115 - learning_rate: 3.1250e-05
# Epoch 39/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9201 - loss: 0.2804 - precision_6: 0.8971 - recall_6: 0.9294 - val_accuracy: 0.9143 - val_loss: 0.3080 - val_precision_6: 0.9035 - val_recall_6: 0.9115 - learning_rate: 3.1250e-05
# Epoch 40/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8928 - loss: 0.3468 - precision_6: 0.8657 - recall_6: 0.9033 - val_accuracy: 0.9143 - val_loss: 0.2961 - val_precision_6: 0.9107 - val_recall_6: 0.9027 - learning_rate: 1.5625e-05
# Epoch 41/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9069 - loss: 0.2835 - precision_6: 0.9119 - recall_6: 0.8873 - val_accuracy: 0.9265 - val_loss: 0.2973 - val_precision_6: 0.9204 - val_recall_6: 0.9204 - learning_rate: 1.5625e-05
# Epoch 42/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9094 - loss: 0.3245 - precision_6: 0.8708 - recall_6: 0.9358 - val_accuracy: 0.9265 - val_loss: 0.2961 - val_precision_6: 0.9130 - val_recall_6: 0.9292 - learning_rate: 1.5625e-05
# Epoch 43/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9133 - loss: 0.3027 - precision_6: 0.8794 - recall_6: 0.9339 - val_accuracy: 0.9184 - val_loss: 0.2974 - val_precision_6: 0.9043 - val_recall_6: 0.9204 - learning_rate: 1.5625e-05
# Epoch 44/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9259 - loss: 0.2978 - precision_6: 0.9280 - recall_6: 0.9112 - val_accuracy: 0.9265 - val_loss: 0.2999 - val_precision_6: 0.9130 - val_recall_6: 0.9292 - learning_rate: 7.8125e-06
# Epoch 45/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9019 - loss: 0.3066 - precision_6: 0.8805 - recall_6: 0.9073 - val_accuracy: 0.9265 - val_loss: 0.2996 - val_precision_6: 0.9204 - val_recall_6: 0.9204 - learning_rate: 7.8125e-06
# Epoch 46/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8997 - loss: 0.3207 - precision_6: 0.9093 - recall_6: 0.8873 - val_accuracy: 0.9306 - val_loss: 0.2945 - val_precision_6: 0.9211 - val_recall_6: 0.9292 - learning_rate: 7.8125e-06
# Epoch 47/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9187 - loss: 0.3119 - precision_6: 0.9341 - recall_6: 0.8960 - val_accuracy: 0.9265 - val_loss: 0.2997 - val_precision_6: 0.9204 - val_recall_6: 0.9204 - learning_rate: 7.8125e-06
# Epoch 48/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9101 - loss: 0.2882 - precision_6: 0.8999 - recall_6: 0.8996 - val_accuracy: 0.9224 - val_loss: 0.3008 - val_precision_6: 0.9196 - val_recall_6: 0.9115 - learning_rate: 7.8125e-06
# Epoch 49/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8772 - loss: 0.3677 - precision_6: 0.8635 - recall_6: 0.8645 - val_accuracy: 0.9265 - val_loss: 0.2998 - val_precision_6: 0.9204 - val_recall_6: 0.9204 - learning_rate: 7.8125e-06
# Epoch 50/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8852 - loss: 0.3463 - precision_6: 0.8527 - recall_6: 0.8931 - val_accuracy: 0.9224 - val_loss: 0.3017 - val_precision_6: 0.9196 - val_recall_6: 0.9115 - learning_rate: 3.9063e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9244 - loss: 0.3219 - precision_6: 0.9620 - recall_6: 0.9148
# Test Loss: 0.2799, Test Accuracy: 0.9333, Test Precision: 0.9434, Test Recall: 0.9091
# Training stopped at Epoch: 0, Time Taken: 32.82 sec

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

plt.figure(figsize=(12, 4))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        65
#            1       0.94      0.91      0.93        55
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.93      0.93       120
# weighted avg       0.93      0.93      0.93       120
